# %% [markdown]
# # CatsDogsPanda Image Classification using MiniVGGNet

# %% [markdown]
# **Objective:** Classify the CatsDogsPanda images using MiniVGGNet

# %% [markdown]
# ## About MiniVGGNet
#
# * The 3x3 kernels/filter are being used through out the architecture.
# * The VGG16 & VGG19 architecture use the filters to increasing depth 16 and 19 layers respectively.
# * Stacks multiple Conv and Relu layers before the pool layers.

# %% [markdown]
# ## Define MiniVGGNet

# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Activation, Flatten, Dense, Dropout

# %%
#?Conv2D
#?MaxPooling2D

# %%
#define miniVGGNet

# input size: 3x3 filters, num of filters 32
# then : 3x3 filters, num of filters 64
#
# 2 sets of Conv -> Relu -> Conv -> Relu -> Pool 
# followed by, FC -> Relu -> FC -> Softmax
def miniVGGNet(width, height, depth, num_classes):
    
    model = Sequential()
    
    inputShape = (height, width, depth)
    pad = 'same'
    
    # first set
    model.add(Conv2D(32, (3,3), input_shape=inputShape, padding=pad))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3,3), padding=pad))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    #model.add(Dropout(0.25))
    
    # second set
    model.add(Conv2D(64, (3,3), padding=pad))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3,3), padding=pad))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    #model.add(Dropout(0.25))
    
    #FC
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    
    #FC + softmax
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
    
    model.summary()
    return model

# %% [markdown]
# ## Read all Images

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pathlib
import glob
import random
import os

# %%
print('numpy: ', np.__version__)
print('opencv: ', cv2.__version__)
# Out:
# numpy:  1.14.2
# opencv:  3.4.4

# %%
ImageDir = '../datasets/animals'

# recursively go over the datset folder and get the file names.
ImageList = list(pathlib.Path(ImageDir).rglob('*.jpg'))
print(len(ImageList))
# Out:
# 3000

# %%
## load all the images
## resize them to one size
def preprocess_image(img, width, height, interpolation=cv2.INTER_AREA):
    return( cv2.resize(img, (width, height), interpolation))

# %%
# load all images.
def load_all_images(imageList, verbose=-1):
    data = []
    labels = []

    # go over each image - read them and extract class label from the path
    for (i, imagepath) in enumerate(imageList):
        filename = imagepath.as_posix()
        img = cv2.imread(filename)
        label = filename.split(os.path.sep)[-2]
        img = preprocess_image(img, 32, 32)

        data.append(img)
        labels.append(label)

        if ( verbose > 0 and i > 0 and (i+1) % verbose == 0):
            print('Info: Processed {} / {}'.format(i+1, len(imageList)))


    return(np.array(data), np.array(labels))

# %%
##
print('Load All Images...')
(data, labels) = load_all_images(ImageList, verbose=250)
# Out:
# Load All Images...
# Info: Processed 250 / 3000
# Info: Processed 500 / 3000
# Info: Processed 750 / 3000
# Info: Processed 1000 / 3000
# Info: Processed 1250 / 3000
# Info: Processed 1500 / 3000
# Info: Processed 1750 / 3000
# Info: Processed 2000 / 3000
# Info: Processed 2250 / 3000
# Info: Processed 2500 / 3000
# Info: Processed 2750 / 3000
# Info: Processed 3000 / 3000

# %%
print(data.shape)
# Out:
# (3000, 32, 32, 3)

# %% [markdown]
# ### Normalize the data input

# %%
data = data.astype("float") / 255.0

# %% [markdown]
# ### Split the train and test dataset

# %%
from sklearn.model_selection import train_test_split

# %%
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.25, random_state=123)

# %%
## convert the labels to vector
from sklearn.preprocessing import LabelBinarizer

trainY = LabelBinarizer().fit_transform(trainY)
testY  = LabelBinarizer().fit_transform(testY)

# %%
print(trainY[0:3])
print(testY[0:3])
# Out:
# [[1 0 0]
#  [0 1 0]
#  [1 0 0]]
# [[0 1 0]
#  [0 1 0]
#  [1 0 0]]

# %% [markdown]
# ## Build the Model

# %%
from keras.optimizers import SGD

# %%
sgd = SGD(lr=0.005)
model = miniVGGNet(width=32, height=32, depth=3, num_classes=3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# _________________________________________________________________
# activation_6 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 2,164,771
# Trainable params: 2,164,771
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])

# %% [markdown]
# ## Train and Evaluate

# %%
# ?model.fit

# %%
# train the network
print("Train the network...")
H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=32, epochs=100, verbose=1)
# Out:
# Train the network...
# Train on 2250 samples, validate on 750 samples
# Epoch 1/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 1.0914 - acc: 0.3684 - val_loss: 1.0823 - val_acc: 0.4000
# Epoch 2/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 1.0722 - acc: 0.4551 - val_loss: 1.0553 - val_acc: 0.4453
# Epoch 3/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 1.0355 - acc: 0.4933 - val_loss: 0.9913 - val_acc: 0.5120
# Epoch 4/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.9795 - acc: 0.5218 - val_loss: 1.0205 - val_acc: 0.4427
# Epoch 5/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.9440 - acc: 0.5320 - val_loss: 0.8886 - val_acc: 0.5840
# Epoch 6/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.9151 - acc: 0.5422 - val_loss: 0.9237 - val_acc: 0.5000
# Epoch 7/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.9051 - acc: 0.5502 - val_loss: 0.8997 - val_acc: 0.5480
# Epoch 8/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.8790 - acc: 0.5613 - val_loss: 0.8597 - val_acc: 0.5680
# Epoch 9/100
# 2250/2250 [==============================] - 12s 6ms/step - loss: 0.8647 - acc: 0.5747 - val_loss: 0.8325 - val_acc: 0.5880
# Epoch 10/100
# 2250/2250 [==============================] - 12s 6ms/step - loss: 0.8513 - acc: 0.5929 - val_loss: 0.9232 - val_acc: 0.5120
# Epoch 11/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.8369 - acc: 0.5929 - val_loss: 0.8028 - val_acc: 0.5787
# Epoch 12/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.8205 - acc: 0.6000 - val_loss: 0.9031 - val_acc: 0.5413
# Epoch 13/100
# 2250/2250 [==============================] - 12s 6ms/step - loss: 0.8154 - acc: 0.5991 - val_loss: 0.8020 - val_acc: 0.6067
# Epoch 14/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.8082 - acc: 0.6062 - val_loss: 0.8082 - val_acc: 0.5707
# Epoch 15/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.7987 - acc: 0.6009 - val_loss: 0.7687 - val_acc: 0.6040
# Epoch 16/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.7863 - acc: 0.6213 - val_loss: 0.7889 - val_acc: 0.5773
# Epoch 17/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.7728 - acc: 0.6276 - val_loss: 0.8029 - val_acc: 0.5773
# Epoch 18/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.7558 - acc: 0.6347 - val_loss: 0.8902 - val_acc: 0.5853
# Epoch 19/100
# 2250/2250 [==============================] - 12s 6ms/step - loss: 0.7651 - acc: 0.6227 - val_loss: 0.8352 - val_acc: 0.5947
# Epoch 20/100
# 2250/2250 [==============================] - 18s 8ms/step - loss: 0.7624 - acc: 0.6244 - val_loss: 0.7177 - val_acc: 0.6467
# Epoch 21/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.7404 - acc: 0.6369 - val_loss: 0.7579 - val_acc: 0.6040
# Epoch 22/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.
100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.3274 - acc: 0.8773 - val_loss: 0.9683 - val_acc: 0.6453
# Epoch 86/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.2911 - acc: 0.8871 - val_loss: 0.7164 - val_acc: 0.6893
# Epoch 87/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.2784 - acc: 0.8960 - val_loss: 0.7377 - val_acc: 0.6987
# Epoch 88/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.2912 - acc: 0.8884 - val_loss: 0.8481 - val_acc: 0.6587
# Epoch 89/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.2623 - acc: 0.9084 - val_loss: 0.7242 - val_acc: 0.7027
# Epoch 90/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.2612 - acc: 0.9093 - val_loss: 0.8161 - val_acc: 0.6693
# Epoch 91/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.2306 - acc: 0.9138 - val_loss: 0.8082 - val_acc: 0.6733
# Epoch 92/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.2261 - acc: 0.9196 - val_loss: 0.9642 - val_acc: 0.6333
# Epoch 93/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.1933 - acc: 0.9320 - val_loss: 0.8210 - val_acc: 0.6880
# Epoch 94/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.2092 - acc: 0.9253 - val_loss: 0.7845 - val_acc: 0.6880
# Epoch 95/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.1774 - acc: 0.9400 - val_loss: 0.8539 - val_acc: 0.6733
# Epoch 96/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.1847 - acc: 0.9387 - val_loss: 0.9846 - val_acc: 0.6760
# Epoch 97/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.1869 - acc: 0.9333 - val_loss: 1.1996 - val_acc: 0.6213
# Epoch 98/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.1435 - acc: 0.9542 - val_loss: 0.8775 - val_acc: 0.6880
# Epoch 99/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.1342 - acc: 0.9640 - val_loss: 0.9183 - val_acc: 0.6813
# Epoch 100/100
# 2250/2250 [==============================] - 13s 6ms/step - loss: 0.2800 - acc: 0.9156 - val_loss: 0.8844 - val_acc: 0.6853

# %%
H.history
# Out:
# {'val_loss': [1.08233118724823,
#   1.055347154935201,
#   0.991260490099589,
#   1.0204545386632284,
#   0.8885716935793558,
#   0.9236584154764811,
#   0.8997049358685811,
#   0.8597301313082377,
#   0.8324580931663513,
#   0.9231506017049154,
#   0.802806696097056,
#   0.9030762828191121,
#   0.8020304476420085,
#   0.8082443259557088,
#   0.768653911113739,
#   0.7889098456700643,
#   0.8029229753812154,
#   0.8902482577959696,
#   0.8351614646911621,
#   0.717716625213623,
#   0.7579079292615255,
#   1.1054474307696025,
#   0.7478818079630534,
#   0.8389540206591288,
#   0.6969705953598022,
#   0.6892123096783956,
#   0.8781243131955465,
#   1.0691656150817872,
#   0.8399469396273295,
#   0.6656654874483744,
#   0.6923755761782329,
#   0.6654548722902934,
#   0.7612850391070048,
#   0.6498411021232605,
#   1.046688282330831,
#   1.1173523473739624,
#   0.6503898572921752,
#   0.6786719772020976,
#   0.6923645768165588,
#   0.6881408388614655,
#   0.6989893684387207,
#   0.8585391052563985,
#   0.8293662198384603,
#   0.8560297147432963,
#   0.9131864763895671,
#   1.1275975305239359,
#   0.8208340675036112,
#   0.8524157201449076,
#   0.6732917132377625,
#   0.7210905388196309,
#   0.6722647344271342,
#   0.6875321637789409,
#   0.6366895333925883,
#   0.6804359108606974,
#   0.6629124755859375,
#   0.6817974813779195,
#   0.7450803442001342,
#   0.7703120155334473,
#   0.9549409510294596,
#   0.5746666667196486,
#   0.5928888889153798,
#   0.5928888889418708,
#   0.5999999999470181,
#   0.5991111110581292,
#   0.606222222328186,
#   0.600888888835907,
#   0.6213333334392972,
#   0.6275555555820465,
#   0.6346666667726305,
#   0.6226666666666667,
#   0.6244444443384807,
#   0.636888888835907,
#   0.6573333334392971,
#   0.6368888889418708,
#   0.6591111110581293,
#   0.6604444444974263,
#   0.6702222222752041,
#   0.6648888889153799,
#   0.6679999999470181,
#   0.6671111112170749,
#   0.6791111110581292,
#   0.6755555556615194,
#   0.6724444444444444,
#   0.6800000001059638,
#   0.6853333332273696,
#   0.6822222222752041,
#   0.6968888889418708,
#   0.6866666666136848,
#   0.7088888889948527,
#   0.7040000000529819,
#   0.7133333332273695,
#   0.7137777778307597,
#   0.7080000001059639,
#   0.7160000001059638,
#   0.720888888835907,
#   0.72,
#   0.7244444443384807,
#   0.7257777778307597,
#   0.7257777777247959,
#   0.7319999999470181,
#   0.742222222328186,
#   0.7444444443914625,
#   0.7426666667726305,
#   0.7373333332273695,
#   0.747111111164093,
#   0.7448888889418708,
#   0.7502222222752041,
#   0.7568888889948527,
#   0.7568888889418708,
#   0.7639999999470181,
#   0.7617777778307597,
#   0.7622222221692403,
#   0.784888888835907,
#   0.7853333332273695,
#   0.7777777778837416,
#   0.7813333332803514,
#   0.7840000000529819,
#   0.7977777777247959,
#   0.8088888888359069,
#   0.7960000000529819,
#   0.8084444443914626,
#   0.8079999998940361,
#   0.8097777778307597,
#   0.8182222221692403,
#   0.8213333333333334,
#   0.8364444443914625,
#   0.8275555555820465,
#   0.8506666666666667,
#   0.8497777778307597,
#   0.8457777778307597,
#   0.8613333332803514,
#   0.8755555554495917,
#   0.8595555555555555,
#   0.8808888888888889,
#   0.8675555554495917,
#   0.8773333332273695,
#   0.8871111111111111,
#   0.896,
#   0.8884444443384806,
#   0.9084444444444445,
#   0.9093333332273695,
#   0.9137777777777778,
#   0.9195555554495918,
#   0.932,
#   0.9253333333333333,
#   0.94,
#   0.9386666665607029,
#   0.9333333332273696,
#   0.9542222222222222,
#   0.964,
#   0.9155555555555556]}

# %%
from sklearn.metrics import confusion_matrix, classification_report #metric

# %%
pred = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1), pred.argmax(axis=1), target_names=["cat", "dog", "panda"]))
# Out:
#               precision    recall  f1-score   support
#
#          cat       0.68      0.47      0.56       252
#          dog       0.55      0.69      0.61       240
#        panda       0.83      0.90      0.86       258
#
#    micro avg       0.69      0.69      0.69       750
#    macro avg       0.69      0.68      0.68       750
# weighted avg       0.69      0.69      0.68       750

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(testY.argmax(axis=1), pred.argmax(axis=1)))
# Out:
# [[118 112  22]
#  [ 51 165  24]
#  [  4  23 231]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(testY.argmax(axis=1), pred.argmax(axis=1)))
# Out:
# 0.6853333333333333

# %% [markdown]
# ## Plot Loss and Accuracy

# %%
import matplotlib.pyplot as plt

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 100), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 100), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, 100), H.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## Save the model

# %%
model.save('CatsDogsPanda_miniVGGNet_weights.hdf5')
